# %% [markdown]
# # Description
# This code convert near field monitor data to far field result\
# Workflow:\
#     1. Load\
#     2. convert to far field result using built-in t3d method\
#     3. Apply NA filter\
#     4. iFFT to imaging result\

# %% [markdown]
# ## Import

# %%
import tidy3d as td
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from hytools import (
    hy_basic as hyb,
    hy_plot as hyp
)

# %% [markdown]
# ## Load

# %%
pass

# %% [markdown]
# ## Work

# %%
pass

# %% [markdown]
# ## Save

# %%
pass
